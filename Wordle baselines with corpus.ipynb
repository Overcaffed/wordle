# %% [markdown]
# # Install Dependencies

# %%
# !pip install stable-baselines3
# !pip install gym
# !pip install pandas
# Out:
# Requirement already satisfied: stable-baselines3 in /home/face9/anaconda3/lib/python3.9/site-packages (1.4.0)
# Requirement already satisfied: cloudpickle in /home/face9/anaconda3/lib/python3.9/site-packages (from stable-baselines3) (1.6.0)
# Requirement already satisfied: matplotlib in /home/face9/anaconda3/lib/python3.9/site-packages (from stable-baselines3) (3.4.3)
# Requirement already satisfied: pandas in /home/face9/anaconda3/lib/python3.9/site-packages (from stable-baselines3) (1.3.4)
# Requirement already satisfied: torch>=1.8.1 in /home/face9/anaconda3/lib/python3.9/site-packages (from stable-baselines3) (1.10.2)
# Requirement already satisfied: numpy in /home/face9/anaconda3/lib/python3.9/site-packages (from stable-baselines3) (1.19.5)
# Requirement already satisfied: gym<0.20,>=0.17 in /home/face9/anaconda3/lib/python3.9/site-packages (from stable-baselines3) (0.19.0)
# Requirement already satisfied: typing_extensions in /home/face9/anaconda3/lib/python3.9/site-packages (from torch>=1.8.1->stable-baselines3) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/face9/anaconda3/lib/python3.9/site-packages (from matplotlib->stable-baselines3) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /home/face9/anaconda3/lib/python3.9/site-packages (from matplotlib->stable-baselines3) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/face9/anaconda3/lib/python3.9/site-packages (from matplotlib->stable-baselines3) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/face9/anaconda3/lib/python3.9/site-packages (from matplotlib->stable-baselines3) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/face9/anaconda3/lib/python3.9/site-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/face9/anaconda3/lib/python3.9/site-packages (from pandas->stable-baselines3) (2021.3)
# Requirement already satisfied: six in /home/face9/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib->stable-baselines3) (1.15.0)
# WARNING: You are using pip version 22.0.3; however, version 23.1.2 is available.
# You should consider upgrading via the '/home/face9/anaconda3/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: gym in /home/face9/anaconda3/lib/python3.9/site-packages (0.19.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /home/face9/anaconda3/lib/python3.9/site-packages (from gym) (1.6.0)
# Requirement already satisfied: numpy>=1.18.0 in /home/face9/anaconda3/lib/python3.9/site-packages (from gym) (1.19.5)
# WARNING: You are using pip version 22.0.3; however, version 23.1.2 is available.
# You should consider upgrading via the '/home/face9/anaconda3/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: pandas in /home/face9/anaconda3/lib/python3.9/site-packages (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/face9/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/face9/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in /home/face9/anaconda3/lib/python3.9/site-packages (from pandas) (1.19.5)
# Requirement already satisfied: six>=1.5 in /home/face9/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# WARNING: You are using pip version 22.0.3; however, version 23.1.2 is available.
# You should consider upgrading via the '/home/face9/anaconda3/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# # Import dependencies

# %%
from gym import Env, Space, spaces
from stable_baselines3 import PPO, A2C
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.envs import IdentityEnvMultiDiscrete
from stable_baselines3.common.evaluation import evaluate_policy

import numpy as np
import random
from IPython.display import clear_output
import random
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

from time import sleep
from itertools import repeat

# %% [markdown]
# # Import Words

# %%
wordleAnswers = pd.read_csv('../wordle/data/wordleAnswers.csv', header=0).values
wordleAnswers = [word[0] for word in wordleAnswers]
playList = pd.read_csv('../wordle/data/wordleWithValues.csv', header=None).sort_values(by=1, ascending=False).values

# Normalise usage to 0-1000
playList = [[word[0], min(1000, word[1] / 100000)] for word in playList]
print('Most used:')
print(playList[0:10])
print('\n# Import dependenciesLeast used:')
print(playList[-10:-1])
# Out:
# Most used:
# [['which', 1000], ['their', 1000], ['would', 1000], ['other', 1000], ['about', 1000], ['there', 1000], ['these', 1000], ['could', 1000], ['first', 1000], ['where', 1000]]
#
# # Import dependenciesLeast used:
# [['ysame', 6e-05], ['ulnad', 6e-05], ['exeem', 6e-05], ['zooea', 6e-05], ['moyls', 5e-05], ['sluse', 5e-05], ['sowms', 4e-05], ['arefy', 4e-05], ['gyeld', 4e-05]]

# %% [markdown]
# # Helper utilities

# %%
def numToChar(num):
    return chr(ord('a') + int(num) - 1)

def numsToWord(numArr):
    word = ''
    for num in numArr:
        word += numToChar(num)
        
    return word
    
def charToNum(char):
    return ord(char) - 97 + 1

def wordToNums(word):
    numArr = np.zeros(5, dtype=np.int64)
    for i in range(5):
        numArr[i] = charToNum(word[i])
        
    return numArr

# %%
def getStartWord(threshold=7000):
    limit = min(len(playList), threshold) - 1
    randomIndex = random.randint(0, limit)
    return playList[randomIndex][0]

# %%
def populateWordChoices(choiceState, words):
    limit = len(choiceState)
    
    ratingState = np.zeros((200), dtype=np.float64)
    
    wordChoices = []
    
    for i in range(limit):
        if i < len(words):
            choiceState[i] = [charToNum(char) for char in words[i][0]]
            ratingState[i] = words[i][1]
        else:
            choiceState[i] = np.zeros([5], dtype=np.uint64)
            ratingState[i] = 0
    
    return choiceState, ratingState

# %%
def flatten(arr):
    return [item for sublist in arr for item in sublist]

def getSuggestedWords(board):
    # No board or first play
    if board[0][0][1] == 0:
        return playList[:200]
    
    badChars = []
    greenChars = [''] * 5
    yellowChars = [[], [], [], [], []]
    
    suggestList = []
    
    for word in board:
        for x, charVal in enumerate(word):
            char = numToChar(charVal[0])
            status = charVal[1]
            
            if status == 0:
                break    
            elif status == 1 and char not in badChars:
                badChars += char
            elif status == 2:
                yellowChars[x] += char
            elif status == 3:
                greenChars[x] = char
            
    for entry in playList:
        playWord = entry[0]
        isWordValid = True
        for x, playChar in enumerate(playWord):
            hasGreenMismatch = greenChars[x] and playChar != greenChars[x]
            hasBadChars = playChar in badChars and playWord.count(playChar) > max(flatten(yellowChars).count(playChar), greenChars.count(playChar))
            hasYellowCharInPosition = playChar in yellowChars[x]
            
            if hasGreenMismatch or hasBadChars or hasYellowCharInPosition:
                isWordValid = False
                break
        
        for yellowChar in [item for sublist in yellowChars for item in sublist]:
            if yellowChar not in playWord:
#                 print(f'grand: {yellowChar} not in {entry[0]}')
                isWordValid = False
                break
        
        if isWordValid:
#             print(f'{entry[0]} is valid!')
            suggestList.append(entry)
        
        if len(suggestList) == 200:
            break
    
    return suggestList

# %% [markdown]
# # Environment (Wordle simulator)

# %%
class WordleTestEnv(Env):
    def __init__(self, targetWords=None, noSpoiler=False, showActionList=False):
        self.targetWords = targetWords
        self.noSpoiler = noSpoiler
        self.showActionList = showActionList
 
        actionNum = 200
        
        self.action_space = spaces.Discrete(actionNum)
        
        board = np.full((6, 5, 2), [27, 4], dtype=np.uint8)
        boardFlat = board.flatten()
        
        wordChoices = np.full((actionNum, 5), [27], dtype=np.uint8)
        wordChoicesFlat = wordChoices.flatten()

        ratings = spaces.Box(low=np.zeros((actionNum)), high=np.full((actionNum), [1000]), dtype=np.float64)
        
        self.observation_space = spaces.Dict({
            'board': spaces.MultiDiscrete(boardFlat, dtype=np.uint8),
            'choices': spaces.MultiDiscrete(wordChoicesFlat, dtype=np.uint8),
            'ratings': ratings
        })
        
        self.state = {
            'board': board,
            'choices': wordChoices,
            'ratings': ratings
        }
        
        self.scores = [0] * 6
        self.scorePlayed = [0] * 5
        self.gamesWon = 0
        self.gamesPlayed = 0
        self.rewardHistory = []

    def step(self, action):
        self.action = action
        actionVal = self.state['choices'][action]
        actionWord = numsToWord(actionVal) if actionVal[0] != 0 else None
        self.attempts += 1
        
        if actionWord:
            reward, winner = self.playWord(actionWord)
            self.row += 1
            self.attempts = 0
        else:
            reward = 0
            winner = False
            
        if winner:
            reward = 7 - self.row
        else:
            reward = 0
        
        self.rewardHistory.append(reward)
        
        suggestList = getSuggestedWords(self.state['board'])
        self.state['choices'], self.state['ratings'] = populateWordChoices(self.state['choices'], suggestList)
        
        self.showStats(reward)
        
        info = {}
        
        shouldBail = self.attempts > 1
        
        done = True if winner or self.row == 6 or self.state['choices'][0][1] == 0 or shouldBail else False
        
        if done:
            self.gamesPlayed += 1
            self.showStats(reward)
            #sleep(0.5)
            
        
        return self._getObs(), reward, done, info
    
    def render(self, mode='live', **kwargs):
        # Render the environment to the screen
        if mode == 'file':
            pass
    
    def reset(self):
        state = self.state
        state['board'] = np.zeros((6, 5, 2), dtype=np.uint64)
        
#         state['choices'] = np.zeros((100, 5), dtype=np.uint8)
        
        suggestList = getSuggestedWords(state['board'])
        state['choices'], state['ratings'] = populateWordChoices(state['choices'], suggestList)
        
#         for row in state['choices']:
#             row = np.zeros(5, dtype=np.uint8)
    
        
    
        if self.targetWords:
            targetWordLen = len(self.targetWords)
            self.startWord = self.targetWords[self.gamesPlayed % targetWordLen]
        else:
            self.startWord = getStartWord()
        
        self.row = 0
        self.state = state
        self.attempts = 0
        return self._getObs()
    
    def playWord(self, actionWord):
        reward = 0
        winner = False
        
        if actionWord == self.startWord:
            winner = True
            self.gamesWon += 1
            self.scores[self.row] += 1
        
        #Apply action
        matchedChars = []
        potentialReward = 0
        greenCount = 0
        
        # Calculate greens first 
        for i, char in enumerate(actionWord):
            if char == self.startWord[i]:
                matchedChars += char
        
        for i, char in enumerate(actionWord):
            charVal = charToNum(char)
            startWordCharMatches = self.startWord.count(char)
            charMatchesSoFar = matchedChars.count(char)
              
            if actionWord[i] == self.startWord[i]:
                letterState = 3
                greenCount += 1
                potentialReward += 5
                
                self.scorePlayed[i] = 2
                matchedChars += char
                
            elif startWordCharMatches > charMatchesSoFar:
                letterState = 2
                
                for j, targetChar in enumerate(self.startWord):
                    #if char == targetChar and self.scorePlayed[j] == 0:
                    reward += 1
                    self.scorePlayed[j] = 1
                        
                matchedChars += char
            else:
                letterState = 1
                
            # Apply to state
            self.state['board'][self.row][i] = [charVal, letterState]
        
        # Apply reward for multi-greens
        reward += (potentialReward * greenCount)
        
        return reward, winner
    
    def showStats(self, reward=None):
        yellowText = '\x1b[6;30;43m'
        greenText = '\x1b[5;30;42m'
        greyText = '\x1b[0;37;1m'
        redText = '\x1b[0;30;41m'
        endColText = '\x1b[0m'
        
        clear_output(wait=True)
        if not self.noSpoiler:
            print('Target word:', self.startWord, '\n')

        print(f'Last action value: {self.action}')
        
        maxWinScore = max(self.scores)
        winScoreModifier = 1 if maxWinScore < 20 else 20 / maxWinScore
        
        for i, wordData in enumerate(self.state['board']):
            # Result column
            rowText = ''
            for letterData in wordData:
                letter = numToChar(int(letterData[0])) if not self.noSpoiler else ' '
                code = int(letterData[1])
                if code == 0 and letterData[0] > 0:
                    rowText += greyText + letter + endColText
                elif code == 0:
                    rowText += ' '
                if code == 1:
                    rowText += letter
                if code == 2:
                    rowText += yellowText + letter + endColText
                if code == 3:
                    rowText += greenText + letter + endColText
            
            #Score Column
            rowScore = self.scores[i]
            
            scoreCharLen = len(str(rowScore))
            bufferText = ' ' * (5)
            scoreText = str(rowScore) if rowScore > 0 else ''
            
            rowText += f'{bufferText}{i + 1}|{greenText}{scoreText}{" " * int(((rowScore * winScoreModifier) - scoreCharLen))}{endColText}'
            print(rowText)

        # Losses row
        losses = self.gamesPlayed - self.gamesWon
        lossCharLen = len(str(rowScore))
        if losses:
            print(f'{bufferText * 2}X|{redText}{losses}{" " * (int(losses * winScoreModifier) - lossCharLen)}{endColText}')
        winRatioText = '0%'
        if self.gamesPlayed > 0:
            winRatioModifier = 100 / self.gamesPlayed
            winPercent = round(self.gamesWon * winRatioModifier)
            winRatioText = f'({winPercent}%)'
        
        print(f'{bufferText * 2}Wins: {self.gamesWon}/{self.gamesPlayed} {winRatioText}')
        
        if reward is not None:
            print(f'{bufferText * 2}Reward: {reward} Average: {self.getRewardAverage()} Score: {self.getScore()}')
        
        # Word choices
        print()
        
        if self.showActionList:
            for i, choiceRow in enumerate(self.state['choices']):
                if choiceRow[0] == 0:
                    break

                choiceWord = numsToWord(choiceRow)
                print(f'{i}: {choiceWord} - {self.state["ratings"][i]}')

    def getRewardAverage(self):
        total = sum(self.rewardHistory)
        count = len(self.rewardHistory)
        
        return round(total / max(1, count), 2)
    
    def getScore(self):
        score = sum([(index + 1) * score for [index, score] in enumerate(self.scores)]) + ((self.gamesPlayed - self.gamesWon) * 10)
        return score
    
    def _getObs(self):
        return {'board': self.state['board'].flatten(), 'choices': self.state['choices'].flatten(), 'ratings': self.state['ratings']}

# %% [markdown]
# # Check environment with random data

# %%
env = WordleTestEnv()
# Import dependencies
env.observation_space.sample()
# print(test['board'].flatten().shape)
# print(test['choices'].flatten().shape)
# Out:
# OrderedDict([('board',
#               array([ 3,  2, 16,  2,  5,  0, 26,  3, 17,  1, 23,  3, 12,  2,  5,  1, 11,
#                       2, 20,  3, 12,  2,  2,  2,  6,  0, 16,  2, 24,  1, 22,  0, 26,  0,
#                       5,  2, 13,  3, 26,  0,  0,  0, 12,  3, 16,  0,  2,  1,  6,  3,  3,
#                       2, 24,  2, 24,  0,  4,  3,  4,  0], dtype=uint8)),
#              ('choices',
#               array([19, 26, 15,  5, 18, 17,  1, 19,  7, 13, 15, 21, 13, 25, 14, 26, 25,
#                      24, 20, 13, 26, 21,  5, 17, 26,  0,  7, 23, 25,  9,  5, 24,  1,  9,
#                      25,  9, 10,  6, 23, 10, 11, 18,  7, 12, 12, 12,  8,  8, 22, 12, 22,
#                      21,  0, 17, 25,  5, 18, 15, 15, 17, 12, 14,  5,  4, 15,  0,  0, 22,
#                       8, 19, 26,  4,  5,  8, 17, 19, 13,  7,  3, 21,  0, 21, 23,  2, 16,
#                      21, 11, 12, 20,  0, 25,  0, 14, 19,  2, 25, 16, 21, 19, 19, 11,  8,
#                      14, 22, 13,  8,  8, 20, 17,  5, 17, 20, 18,  9, 18, 17,  4, 17,  0,
#                      14, 21,  2,  6, 26,  9, 13, 11, 15, 25, 16, 25, 11,  7, 18, 21,  4,
#                       1, 23, 12, 17, 13, 18, 12, 16, 13,  7, 23, 10,  5, 11, 11,  9, 13,
#                       8, 19,  0,  6, 15,  1, 23, 14, 19, 25, 18, 17, 17, 12, 13,  6, 18,
#                      22, 24, 16, 18, 22, 17, 25, 13, 14,  9, 13,  4,  0, 24, 14, 17, 22,
#                      6.38917346e+02, 4.70268615e+02, 9.16874019e+02, 7.26355619e+02]))])

# %%
from stable_baselines3.common.env_checker import check_env
check_env(env)
# Out:
# Target word: wimps
#
# Last action value: 140
# ideas     1|
#           2|
#           3|
#           4|
#           5|
#           6|
#           Wins: 0/0 0%
#           Reward: 0 Average: 0.0 Score: 0

# %%
env = WordleTestEnv()

episodes = 10
for episode in range(1, episodes+1):
    env.reset()
    done = False
    score = 0 
    
    while not done:
#         env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward

    print('Episode:{} Score:{}'.format(episode, score))
# Out:
# Target word: swami
#
# Last action value: 173
# doing     1|
# bills     2|
# shtik     3|
#           4|
#           5|
#           6|
#           X|10
#           Wins: 0/10 (0%)
#           Reward: 0 Average: 0.0 Score: 100
#
# Episode:10 Score:0

# %% [markdown]
# # Create baselines Model for agent

# %%
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.env_util import make_vec_env

# %%
def make_env(rank, seed=0):
    """
    Utility function for multiprocessed env.
    
    :param seed: (int) the inital seed for RNG
    :param rank: (int) index of the subprocess
    """
    def _init():
        env = WordleTestEnv()
        # Important: use a different seed for each environment
        env.seed(seed + rank)
        return env

    print('Making env: ', rank)
    return _init

# %%
netArch=[256, 256, 128]

# %%
tbLogPath = '/home/face9/logs'
env = WordleTestEnv()
env = DummyVecEnv([lambda: env])
model = PPO('MultiInputPolicy', env, learning_rate=1e-4, verbose = 1, tensorboard_log=tbLogPath, policy_kwargs={'net_arch':netArch})
# model = PPO.load('/home/face9/dev/wordle/models/PPO_RLW_782')
# Out:
# Using cpu device

# %%
env = WordleTestEnv(['abode', 'hello'], noSpoiler=False)
evaluate_policy(model, env,  n_eval_episodes=8)
print(env.getScore())
# Out:
# Target word: hello
#
# Last action value: 72
# force     1|
# aweto     2|
#           3|
#           4|
#           5|
#           6|
#           X|8
#           Wins: 0/8 (0%)
#           Reward: 0 Average: 0.0 Score: 80
#
# 80

# %%
lowestScore = 10000
realWords = 300

while(True):
    env = WordleTestEnv()
    env = DummyVecEnv([lambda: env])
    model.env = env
    model.learn(total_timesteps=32768)
    testEnv = WordleTestEnv(wordleAnswers[0:realWords], noSpoiler=True)
    evaluate_policy(model, testEnv, n_eval_episodes = realWords)
    score = testEnv.getScore()
    
    if score < lowestScore:
        model.save(f'/home/face9/dev/wordle/models/DevClub_{score}')
        lowestScore = score
        print(f'Model saved. Score: {score} Lowest Score: {lowestScore}')
        sleep(3)
    else:
        print(f'Model NOT saved. Score: {score} Lowest Score: {lowestScore}')
        sleep(3)
# Out:
# Target word: iller
#
# Last action value: 135
# final     1|2
#           2|3
#           3|7
#           4|5
#           5|
#           6|
#           X|1340
#           Wins: 17/1357 (1%)
#           Reward: 0 Average: 0.01 Score: 13449
#
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 23          |
# |    iterations           | 3           |
# |    time_elapsed         | 260         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014798386 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.27       |
# |    explained_variance   | -0.0623     |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0457     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0417     |
# |    value_loss           | 0.0742      |
# -----------------------------------------

# %% [markdown]
# states = env.observation_space.shape
# actions = env.action_space.n

# %%
tbLogPath = '/home/face9/logs'
# !tensorboard --logdir={tbLogPath}
# Out:
# 2022-02-22 23:29:42.032344: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.8.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %%
def build_model(states, actions):
    model = Sequential()
#     model.add(Reshape((6, 10), input_shape=(1, 6, 5, 2)))
#     model.add(LSTM(64, activation='tanh', recurrent_activation='sigmoid', recurrent_dropout=0, unroll=False, use_bias='True'))
#     model.add(LSTM(128, activation='tanh', return_sequences=False))
    model.add(Dense(2048, activation='relu', input_shape=(1, 6, 5, 2)))
    model.add(Dense(2048, activation='relu'))
    model.add(Dense(2048, activation='relu'))
    model.add(Flatten())
    model.add(Dense(actions, activation='relu'))
    model.add(Dense(actions, activation='relu'))
    model.add(Dense(actions, activation='linear'))
    return model

# %%
del model

# %%
model = build_model(states, actions)

# %%
model.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_85 (Dense)             (None, 1, 6, 5, 2048)     6144
# _________________________________________________________________
# dense_86 (Dense)             (None, 1, 6, 5, 2048)     4196352
# _________________________________________________________________
# dense_87 (Dense)             (None, 1, 6, 5, 2048)     4196352
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 61440)             0
# _________________________________________________________________
# dense_88 (Dense)             (None, 26)                1597466
# _________________________________________________________________
# dense_89 (Dense)             (None, 26)                702
# _________________________________________________________________
# dense_90 (Dense)             (None, 26)                702
# =================================================================
# Total params: 9,997,718
# Trainable params: 9,997,718
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = keras.models.load_model('/home/face9/dev/OpenAI-Reinforcement-Learning-with-Custom-Environment/wordle')
# Out:
# 2022-02-18 11:45:14.314492: W tensorflow/core/common_runtime/bfc_allocator.cc:456] Allocator (GPU_0_bfc) ran out of memory trying to allocate 202.30MiB (rounded to 212123648)requested by op dense_11/kernel/Initializer/random_uniform/RandomUniform
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2022-02-18 11:45:14.314551: I tensorflow/core/common_runtime/bfc_allocator.cc:991] BFCAllocator dump for GPU_0_bfc
# 2022-02-18 11:45:14.314562: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (256): 	Total Chunks: 98, Chunks in use: 98. 24.5KiB allocated for chunks. 24.5KiB in use in bin. 1.9KiB client-requested in use in bin.
# 2022-02-18 11:45:14.314568: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (512): 	Total Chunks: 18, Chunks in use: 18. 11.2KiB allocated for chunks. 11.2KiB in use in bin. 9.9KiB client-requested in use in bin.
# 2022-02-18 11:45:14.314572: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (1024): 	Total Chunks: 1, Chunks in use: 1. 1.2KiB allocated for chunks. 1.2KiB in use in bin. 1.0KiB client-requested in use in bin.
# 2022-02-18 11:45:14.314576: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-02-18 11:45:14.314580: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (4096): 	Total Chunks: 1, Chunks in use: 1. 7.5KiB allocated for chunks. 7.5KiB in use in bin. 7.5KiB client-requested in use in bin.
# 2022-02-18 11:45:14.314584: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (8192): 	Total Chunks: 8, Chunks in use: 8. 96.0KiB allocated for chunks. 96.0KiB in use in bin. 96.0KiB client-requested in use in bin.
# 2022-02-18 11:45:14.314588: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (16384): 	Total Chunks: 8, Chunks in use: 8. 128.0KiB allocated for chunks. 128.0KiB in use in bin. 128.0KiB client-requested in use in bin.
# 2022-02-18 11:45:14.314593: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (32768): 	Total Chunks: 11, Chunks in use: 11. 558.2KiB allocated for chunks. 558.2KiB in use in bin. 556.3KiB client-requested in use in bin.
# 2022-02-18 11:45:14.314596: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (65536): 	Total Chunks: 1, Chunks in use: 0. 72.0KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-02-18 11:45:14.314600: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-02-18 11:45:14.314603: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-02-18 11:45:14.314607: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (524288): 	Total Chunks: 1, Chunks in use: 0. 720.5KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-02-18 11:45:14.314611: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (1048576): 	Total Chunks: 1, Chunks in use: 0. 1.58MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-02-18 11:45:14.314614: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (2097152): 	Total Chunks: 1, Chunks in use: 0. 2.07MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-02-18 11:45:14.314617: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-02-18 11:45:14.314639: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (8388608): 	Total Chunks: 6, Chunks in use: 5. 90.00MiB allocated for chunks. 75.00MiB in use in bin. 75.00MiB client-requested in use in bin.
# 2022-02-18 11:45:14.314643: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-02-18 11:45:14.314648: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (33554432): 	Total Chunks: 3, Chunks in use: 3. 142.24MiB allocated for chunks. 142.24MiB in use in bin. 142.24MiB client-requested in use in bin.
# 2022-02-18 11:45:14.314651: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-02-18 11:45:14.314656: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (134217728): 	Total Chunks: 5, Chunks in use: 4. 981.42MiB allocated for chunks. 824.12MiB in use in bin. 809.19MiB client-requested in use in bin.
# 2022-02-18 11:45:14.314660: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (268435456): 	Total Chunks: 4, Chunks in use: 4. 2.19GiB allocated for chunks. 2.19GiB in use in bin. 2.07GiB client-requested in use in bin.
# 2022-02-18 11:45:14.314665: I tensorflow/core/common_runtime/bfc_allocator.cc:1014] Bin for 202.30MiB was 128.00MiB, Chunk State:
# 2022-02-18 11:45:14.314679: I tensorflow/core/common_runtime/bfc_allocator.cc:1020]   Size: 157.30MiB | Requested Size: 0B | in_use: 0 | bin_num: 19, prev:   Size: 15.00MiB | Requested Size: 15.00MiB | in_use: 1 | bin_num: -1, for: training/Adam/Adam/update_dense_6/kernel/ResourceApplyAdam, stepid: 44, last_action: 13055601068217569, next:   Size: 202.30MiB | Requested Size: 202.30MiB | in_use: 1 | bin_num: -1, for: training/Adam/Adam/update_dense_7/kernel/ResourceApplyAdam, stepid: 44, last_action: 13055601068217551, for: UNUSED, stepid: 0, last_action: 0
# 2022-02-18 11:45:14.314682: I tensorflow/core/common_runtime/bfc_allocator.cc:1027] Next region of size 3629514752
# 2022-02-18 11:45:14.314691: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 610100000 of size 1280 by op ScratchBuffer action_count 13055601068216321 step 0 next 1
# 2022-02-18 11:45:14.314696: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 610100500 of size 512 by op dense/bias/Initializer/zeros action_count 13055601068216322 step 0 next 2
# 2022-02-18 11:45:14.314699: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 610100700 of size 256 by op dense/kernel/Initializer/random_uniform/min action_count 13055601068216323 step 0 next 3
# 2022-02-18 11:45:14.314702: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 610100800 of size 256 by op dense/kernel/Initializer/random_uniform/sub action_count 13055601068216324 step 0 next 4
# 2022-02-18 11:45:14.314706: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 610100900 of size 256 by op dense_1/bias/Initializer/zeros action_count 13055601068216325 step 0 next 5
# 2022-02-18 11:45:14.314709: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 610100a00 of size 256 by op dense_1/kernel/Initializer/random_uniform/min action_count 13055601068216326 step 0 next 6
# 2022-02-18 11:45:14.314712: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 610100b00 of size 256 by op dense_1/kernel/Initializer/random_uniform/sub action_count 13055601068216327 step 0 next 7
# 2022-02-18 11:45:14.314715: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 610100c00 of size 256 by op dense_1_1/kernel/Initializer/random_uniform/min action_count 13055601068216328 step 0 next 8
# 2022-02-18 11:45:14.314719: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 610100d00 of size 51968 by op dense_2/bias/Initializer/zeros action_count 13055601068216329 step 0 next 9
# 2022-02-18 11:45:14.314722: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010d800 of size 256 by op dense_2/kernel/Initializer/random_uniform/min action_count 13055601068216330 step 0 next 10
# 2022-02-18 11:45:14.314725: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010d900 of size 256 by op dense_2/kernel/Initializer/random_uniform/sub action_count 13055601068216331 step 0 next 11
# 2022-02-18 11:45:14.314728: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010da00 of size 256 by op dense_2_1/kernel/Initializer/random_uniform/min action_count 13055601068216332 step 0 next 12
# 2022-02-18 11:45:14.314732: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010db00 of size 256 by op dense_3/kernel/Initializer/random_uniform/min action_count 13055601068216333 step 0 next 13
# 2022-02-18 11:45:14.314735: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010dc00 of size 256 by op dense_3/kernel/Initializer/random_uniform/sub action_count 13055601068216334 step 0 next 14
# 2022-02-18 11:45:14.314738: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010dd00 of size 256 by op dense_3_1/kernel/Initializer/random_uniform/min action_count 13055601068216335 step 0 next 15
# 2022-02-18 11:45:14.314741: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010de00 of size 256 by op dense_4/kernel/Initializer/random_uniform/min action_count 13055601068216336 step 0 next 16
# 2022-02-18 11:45:14.314744: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010df00 of size 256 by op dense_1_2/bias/Initializer/zeros action_count 13055601068216357 step 0 next 20
# 2022-02-18 11:45:14.314747: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010e000 of size 256 by op dense_1_2/kernel/Initializer/random_uniform/min action_count 13055601068216358 step 0 next 17
# 2022-02-18 11:45:14.314750: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010e100 of size 256 by op dense_1_2/kernel/Initializer/random_uniform/sub action_count 13055601068216359 step 0 next 33
# 2022-02-18 11:45:14.314753: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010e200 of size 256 by op dense_2_2/kernel/Initializer/random_uniform/min action_count 13055601068216361 step 0 next 35
# 2022-02-18 11:45:14.314756: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010e300 of size 256 by op dense_2_2/kernel/Initializer/random_uniform/sub action_count 13055601068216362 step 0 next 36
# 2022-02-18 11:45:14.314759: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010e400 of size 256 by op dense_3_2/kernel/Initializer/random_uniform/min action_count 13055601068216363 step 0 next 37
# 2022-02-18 11:45:14.314762: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010e500 of size 256 by op dense_3_2/kernel/Initializer/random_uniform/sub action_count 13055601068216364 step 0 next 38
# 2022-02-18 11:45:14.314765: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010e600 of size 512 by op dense_5/bias/Initializer/zeros action_count 13055601068216365 step 0 next 39
# 2022-02-18 11:45:14.314768: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010e800 of size 256 by op dense_5/kernel/Initializer/random_uniform/min action_count 13055601068216366 step 0 next 40
# 2022-02-18 11:45:14.314772: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010e900 of size 256 by op dense_5/kernel/Initializer/random_uniform/sub action_count 13055601068216367 step 0 next 41
# 2022-02-18 11:45:14.314776: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010ea00 of size 768 by op dense_5/kernel/Initializer/random_uniform/RandomUniform action_count 13055601068216371 step 6 next 44
# 2022-02-18 11:45:14.314779: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010ed00 of size 512 by op dense_4_1/bias/Initializer/zeros action_count 13055601068216372 step 0 next 45
# 2022-02-18 11:45:14.314782: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010ef00 of size 256 by op dense_4_1/kernel/Initializer/random_uniform/min action_count 13055601068216373 step 0 next 46
# 2022-02-18 11:45:14.314785: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010f000 of size 256 by op dense_4_1/kernel/Initializer/random_uniform/sub action_count 13055601068216374 step 0 next 47
# 2022-02-18 11:45:14.314788: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010f100 of size 256 by op dense_4_2/kernel/Initializer/random_uniform/min action_count 13055601068216375 step 0 next 48
# 2022-02-18 11:45:14.314791: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010f200 of size 256 by op dense_5_1/bias/Initializer/zeros action_count 13055601068216376 step 0 next 49
# 2022-02-18 11:45:14.314794: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010f300 of size 256 by op dense_5_1/kernel/Initializer/random_uniform/min action_count 13055601068216377 step 0 next 50
# 2022-02-18 11:45:14.314797: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010f400 of size 256 by op dense_5_1/kernel/Initializer/random_uniform/sub action_count 13055601068216378 step 0 next 51
# 2022-02-18 11:45:14.314800: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010f500 of size 256 by op dense_5_2/kernel/Initializer/random_uniform/min action_count 13055601068216379 step 0 next 52
# 2022-02-18 11:45:14.314803: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010f600 of size 256 by op dense_6/kernel/Initializer/random_uniform/min action_count 13055601068216381 step 0 next 54
# 2022-02-18 11:45:14.314806: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010f700 of size 256 by op dense_6/kernel/Initializer/random_uniform/sub action_count 13055601068216382 step 0 next 55
# 2022-02-18 11:45:14.314810: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010f800 of size 256 by op dense_6_1/kernel/Initializer/random_uniform/min action_count 13055601068216383 step 0 next 56
# 2022-02-18 11:45:14.314813: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010f900 of size 256 by op dense_7/kernel/Initializer/random_uniform/min action_count 13055601068216385 step 0 next 58
# 2022-02-18 11:45:14.314816: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010fa00 of size 256 by op dense_7/kernel/Initializer/random_uniform/sub action_count 13055601068216386 step 0 next 59
# 2022-02-18 11:45:14.314819: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010fb00 of size 256 by op dense_7_1/kernel/Initializer/random_uniform/min action_count 13055601068216387 step 0 next 60
# 2022-02-18 11:45:14.314822: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010fc00 of size 768 by op dense_4_1/kernel/Initializer/random_uniform/RandomUniform action_count 13055601068216389 step 9 next 62
# 2022-02-18 11:45:14.314825: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 61010ff00 of size 256 by op count_2/Initializer/zeros action_count 13055601068216408 step 0 next 77
# 2022-02-18 11:45:14.314828: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 610110000 of size 512 by op SameWorkerRecvDone action_count 13055601068216449 step 0 next 68
# 2022-02-18 11:45:14.314832: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 610110200 of size 256 by op training/Adam/beta_1/Initializer/initial_value action_count 13055601068217413 step 0 next 74
# 2022-02-18 11:45:14.314835: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 610
I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 693d2cb00 of size 51968 by op dense_7/bias/Initializer/zeros action_count 13055601068216384 step 0 next 57
# 2022-02-18 11:45:14.314918: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 693d39600 of size 212123648 by op dense_7/kernel/Initializer/random_uniform/RandomUniform action_count 13055601068216388 step 9 next 61
# 2022-02-18 11:45:14.314921: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6a0785600 of size 212123648 by op SameWorkerRecvDone action_count 13055601068216458 step 0 next 63
# 2022-02-18 11:45:14.314924: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6ad1d1600 of size 12288 by op dense_5_1/kernel/Initializer/random_uniform/RandomUniform action_count 13055601068216391 step 9 next 64
# 2022-02-18 11:45:14.314927: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6ad1d4600 of size 12288 by op SameWorkerRecvDone action_count 13055601068216447 step 0 next 65
# 2022-02-18 11:45:14.314930: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6ad1d7600 of size 15728640 by op dense_6/kernel/Initializer/random_uniform/RandomUniform action_count 13055601068216393 step 9 next 66
# 2022-02-18 11:45:14.314933: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6ae0d7600 of size 51968 by op SameWorkerRecvDone action_count 13055601068216448 step 0 next 83
# 2022-02-18 11:45:14.314936: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6ae0e4100 of size 16384 by op SameWorkerRecvDone action_count 13055601068216452 step 0 next 78
# 2022-02-18 11:45:14.314939: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6ae0e8100 of size 12288 by op training/Adam/dense_5_1/kernel/m/Initializer/zeros action_count 13055601068217419 step 0 next 67
# 2022-02-18 11:45:14.314942: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6ae0eb100 of size 16384 by op training/Adam/dense_6/bias/m/Initializer/zeros action_count 13055601068217420 step 0 next 80
# 2022-02-18 11:45:14.314945: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6ae0ef100 of size 15728640 by op training/Adam/dense_6/kernel/m/Initializer/zeros action_count 13055601068217421 step 0 next 81
# 2022-02-18 11:45:14.314949: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6aefef100 of size 51968 by op training/Adam/dense_7/bias/m/Initializer/zeros action_count 13055601068217422 step 0 next 84
# 2022-02-18 11:45:14.314952: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6aeffbc00 of size 227783936 by op training/Adam/dense_7/kernel/m/Initializer/zeros action_count 13055601068217423 step 0 next 73
# 2022-02-18 11:45:14.314955: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bc937100 of size 15728640 by op SameWorkerRecvDone action_count 13055601068216460 step 0 next 71
# 2022-02-18 11:45:14.314958: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd837100 of size 256 by op loss_3/Cast action_count 13055601068217426 step 0 next 86
# 2022-02-18 11:45:14.314961: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd837200 of size 256 by op training/Adam/add/y action_count 13055601068217427 step 0 next 87
# 2022-02-18 11:45:14.314964: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd837300 of size 256 by op training/Adam/Const action_count 13055601068217428 step 0 next 88
# 2022-02-18 11:45:14.314968: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd837400 of size 256 by op loss_2/mul/x action_count 13055601068217429 step 0 next 89
# 2022-02-18 11:45:14.314971: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd837500 of size 256 by op training/Adam/gradients/gradients/loss_2/Square_grad/Const action_count 13055601068217430 step 0 next 90
# 2022-02-18 11:45:14.314974: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd837600 of size 256 by op training/Adam/Adam/Const action_count 13055601068217431 step 0 next 91
# 2022-02-18 11:45:14.314977: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd837700 of size 768 by op training/Adam/Adam/update_dense_4_1/kernel/ResourceApplyAdam action_count 13055601068217605 step 44 next 104
# 2022-02-18 11:45:14.314980: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd837a00 of size 768 by op training/Adam/Adam/update_dense_4_1/kernel/ResourceApplyAdam action_count 13055601068217606 step 44 next 130
# 2022-02-18 11:45:14.314983: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd837d00 of size 256 by op SameWorkerRecvDone action_count 13055601068217620 step 0 next 112
# 2022-02-18 11:45:14.314986: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd837e00 of size 256 by op dense_9/kernel/Initializer/random_uniform/min action_count 13055601068217849 step 0 next 93
# 2022-02-18 11:45:14.314989: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd837f00 of size 256 by op dense_9/kernel/Initializer/random_uniform/sub action_count 13055601068217850 step 0 next 96
# 2022-02-18 11:45:14.314993: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd838000 of size 256 by op dense_10/kernel/Initializer/random_uniform/min action_count 13055601068217851 step 0 next 132
# 2022-02-18 11:45:14.314996: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd838100 of size 256 by op dense_10/kernel/Initializer/random_uniform/sub action_count 13055601068217852 step 0 next 103
# 2022-02-18 11:45:14.314999: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd838200 of size 256 by op dense_11/kernel/Initializer/random_uniform/min action_count 13055601068217853 step 0 next 138
# 2022-02-18 11:45:14.315002: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd838300 of size 256 by op dense_11/kernel/Initializer/random_uniform/sub action_count 13055601068217854 step 0 next 137
# 2022-02-18 11:45:14.315006: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd838400 of size 256 by op dense_12/kernel/Initializer/random_uniform/min action_count 13055601068217855 step 0 next 133
# 2022-02-18 11:45:14.315009: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd838500 of size 256 by op dense_12/kernel/Initializer/random_uniform/sub action_count 13055601068217856 step 0 next 102
# 2022-02-18 11:45:14.315012: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd838600 of size 256 by op dense_13/kernel/Initializer/random_uniform/min action_count 13055601068217857 step 0 next 131
# 2022-02-18 11:45:14.315015: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd838700 of size 256 by op dense_14/kernel/Initializer/random_uniform/min action_count 13055601068217858 step 0 next 136
# 2022-02-18 11:45:14.315018: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd838800 of size 256 by op dense_15/kernel/Initializer/random_uniform/min action_count 13055601068217859 step 0 next 142
# 2022-02-18 11:45:14.315021: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd838900 of size 256 by op dense_16/bias/Initializer/zeros action_count 13055601068217860 step 0 next 143
# 2022-02-18 11:45:14.315024: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd838a00 of size 256 by op dense_16/kernel/Initializer/random_uniform/min action_count 13055601068217861 step 0 next 134
# 2022-02-18 11:45:14.315027: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd838b00 of size 256 by op dense_16/kernel/Initializer/random_uniform/sub action_count 13055601068217862 step 0 next 141
# 2022-02-18 11:45:14.315030: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd838c00 of size 256 by op dense_17/kernel/Initializer/random_uniform/min action_count 13055601068217863 step 0 next 139
# 2022-02-18 11:45:14.315033: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd838d00 of size 256 by op dense_17/kernel/Initializer/random_uniform/sub action_count 13055601068217864 step 0 next 135
# 2022-02-18 11:45:14.315036: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd838e00 of size 256 by op dense_18/kernel/Initializer/random_uniform/min action_count 13055601068217865 step 0 next 140
# 2022-02-18 11:45:14.315039: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd838f00 of size 256 by op dense_19/kernel/Initializer/random_uniform/min action_count 13055601068217866 step 0 next 144
# 2022-02-18 11:45:14.315043: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd839000 of size 256 by op dense_20/kernel/Initializer/random_uniform/min action_count 13055601068217867 step 0 next 145
# 2022-02-18 11:45:14.315046: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd839100 of size 256 by op dense_21/bias/Initializer/zeros action_count 13055601068217868 step 0 next 146
# 2022-02-18 11:45:14.315049: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd839200 of size 256 by op dense_21/kernel/Initializer/random_uniform/min action_count 13055601068217869 step 0 next 147
# 2022-02-18 11:45:14.315051: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd839300 of size 256 by op dense_22/kernel/Initializer/random_uniform/min action_count 13055601068217870 step 0 next 148
# 2022-02-18 11:45:14.315055: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd839400 of size 256 by op dense_23/kernel/Initializer/random_uniform/min action_count 13055601068217872 step 0 next 92
# 2022-02-18 11:45:14.315057: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd839500 of size 256 by op training/Adam/Adam/update_dense_5_1/bias/ResourceApplyAdam action_count 13055601068217581 step 44 next 101
# 2022-02-18 11:45:14.315060: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 6bd839600 of size 1657344 by op UNUSED action_count 13055601068217832 step 51 next 98
# 2022-02-18 11:45:14.315063: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd9ce000 of size 256 by op training/Adam/Adam/AssignAddVariableOp action_count 13055601068217610 step 44 next 99
# 2022-02-18 11:45:14.315066: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd9ce100 of size 256 by op training/Adam/Adam/update_dense_5_1/bias/ResourceApplyAdam action_count 13055601068217579 step 44 next 123
# 2022-02-18 11:45:14.315069: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bd9ce200 of size 256 by op training/Adam/Adam/update_dense_5_1/bias/ResourceApplyAdam action_count 13055601068217580 step 44 next 107
# 2022-02-18 11:45:14.315072: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 6bd9ce300 of size 737792 by op UNUSED action_count 13055601068217841 step 51 next 94
# 2022-02-18 11:45:14.315075: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bda82500 of size 16384 by op training/Adam/Adam/update_dense_6/bias/ResourceApplyAdam action_count 13055601068217564 step 44 next 95
# 2022-02-18 11:45:14.315078: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bda86500 of size 16384 by op training/Adam/Adam/update_dense_6/bias/ResourceApplyAdam action_count 13055601068217565 step 44 next 113
# 2022-02-18 11:45:14.315081: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bda8a500 of size 16384 by op training/Adam/Adam/update_dense_6/bias/ResourceApplyAdam action_count 13055601068217566 step 44 next 121
# 2022-02-18 11:45:14.315084: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bda8e500 of size 12288 by op training/Adam/Adam/update_dense_5_1/kernel/ResourceApplyAdam action_count 13055601068217587 step 44 next 125
# 2022-02-18 11:45:14.315087: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bda91500 of size 12288 by op training/Adam/Adam/update_dense_5_1/kernel/ResourceApplyAdam action_count 13055601068217588 step 44 next 126
# 2022-02-18 11:45:14.315090: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bda94500 of size 256 by op SameWorkerRecvDone action_count 13055601068217612 step 0 next 129
# 2022-02-18 11:45:14.315092: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bda94600 of size 256 by op SameWorkerRecvDone action_count 13055601068217615 step 0 next 114
# 2022-02-18 11:45:14.315095: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bda94700 of size 512 by op training/Adam/Adam/update_dense_4_1/bias/ResourceApplyAdam action_count 13055601068217598 step 44 next 124
# 2022-02-18 11:45:14.315098: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bda94900 of size 512 by op training/Adam/Adam/update_dense_4_1/bias/ResourceApplyAdam action_count 13055601068217599 step 44 next 127
# 2022-02-18 11:45:14.315101: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bda94b00 of size 512 by op training/Adam/Adam/update_dense_4_1/bias/ResourceApplyAdam action_count 13055601068217600 step 44 next 128
# 2022-02-18 11:45:14.315104: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bda94d00 of size 51968 by op dense_23/bias/Initializer/zeros action_count 13055601068217871 step 0 next 149
# 2022-02-18 11:45:14.315107: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa1800 of size 256 by op dense_24/kernel/Initializer/random_uniform/min action_count 13055601068217873 step 0 next 150
# 2022-02-18 11:45:14.315110: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa1900 of size 256 by op dense_25/kernel/Initializer/random_uniform/min action_count 13055601068217874 step 0 next 151
# 2022-02-18 11:45:14.315113: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa1a00 of size 256 by op dense_25/kernel/Initializer/random_uniform/sub action_count 13055601068217875 step 0 next 152
# 2022-02-18 11:45:14.315116: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa1b00 of size 16384 by op dense_26/bias/Initializer/zeros action_count 13055601068217876 step 0 next 153
# 2022-02-18 11:45:14.315119: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa5b00 of size 256 by op dense_26/kernel/Initializer/random_uniform/min action_count 13055601068217877 step 0 next 154
# 2022-02-18 11:45:14.315122: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa5c00 of size 256 by op dense_26/kernel/Initializer/random_uniform/sub action_count 13055601068217878 step 0 next 155
# 2022-02-18 11:45:14.315125: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa5d00 of size 256 by op dense_27/kernel/Initializer/random_uniform/min action_count 13055601068217879 step 0 next 156
# 2022-02-18 11:45:14.315128: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa5e00 of size 512 by op dense_28/bias/Initializer/zeros action_count 13055601068217880 step 0 next 157
# 2022-02-18 11:45:14.315131: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa6000 of size 256 by op dense_28/kernel/Initializer/random_uniform/min action_count 13055601068217881 step 0 next 158
# 2022-02-18 11:45:14.315134: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa6100 of size 256 by op dense_29/kernel/Initializer/random_uniform/min action_count 13055601068217882 step 0 next 159
# 2022-02-18 11:45:14.315138: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa6200 of size 7680 by op dense_30/bias/Initializer/zeros action_count 13055601068217883 step 0 next 160
# 2022-02-18 11:45:14.315141: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa8000 of size 256 by op dense_30/kernel/Initializer/random_uniform/min action_count 13055601068217884 step 0 next 161
# 2022-02-18 11:45:14.315144: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa8100 of size 256 by op dense_30/kernel/Initializer/random_uniform/sub action_count 13055601068217885 step 0 next 162
# 2022-02-18 11:45:14.315148: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa8200 of size 256 by op dense_31/kernel/Initializer/random_uniform/min action_count 13055601068217886 step 0 next 163
# 2022-02-18 11:45:14.315150: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa8300 of size 256 by op dense_31/kernel/Initializer/random_uniform/sub action_count 13055601068217887 step 0 next 164
# 2022-02-18 11:45:14.315153: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa8400 of size 256 by op dense_8/kernel/Initializer/random_uniform/min action_count 13055601068217888 step 0 next 165
# 2022-02-18 11:45:14.315157: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa8500 of size 16384 by op dense_9/kernel/Initializer/random_uniform/RandomUniform action_count 13055601068217889 step 53 next 166
# 2022-02-18 11:45:14.315159: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 6bdaac500 of size 73728 by op UNUSED action_count 0 step 0 next 105
# 2022-02-18 11:45:14.315162: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdabe500 of size 51968 by op training/Adam/Adam/update_dense_7/bias/ResourceApplyAdam action_count 13055601068217555 step 44 next 116
# 2022-02-18 11:45:14.315165: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdacb000 of size 51968 by op training/Adam/Adam/update_dense_7/bias/ResourceApplyAdam action_count 13055601068217556 step 44 next 117
# 2022-02-18 11:45:14.315168: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdad7b00 of size 51968 by op training/Adam/Adam/update_dense_7/bias/ResourceApplyAdam action_count 13055601068217557 step 44 next 118
# 2022-02-18 11:45:14.315171: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 6bdae4600 of size 2174720 by op UNUSED action_count 13055601068217812 step 0 next 106
# 2022-02-18 11:45:14.315173: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdcf7500 of size 256 by op SameWorkerRecvDone action_count 13055601068217616 step 0 next 109
# 2022-02-18 11:45:14.315176: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdcf7600 of size 256 by op SameWorkerRecvDone action_count 13055601068217623 step 0 next 108
# 2022-02-18 11:45:14.315179: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdcf7700 of size 256 by op SameWorkerRecvDone action_count 13055601068217624 step 0 next 97
# 2022-02-18 11:45:14.315182: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdcf7800 of size 256 by op SameWorkerRecvDone action_count 13055601068217619 step 0 next 110
# 2022-02-18 11:45:14.315184: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdcf7900 of size 256 by op SameWorkerRecvDone action_count 13055601068217611 step 0 next 111
# 2022-02-18 11:45:14.315187: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 6bdcf7a00 of size 15728896 by op UNUSED action_count 13055601068217821 step 51 next 120
# 2022-02-18 11:45:14.315190: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bebf7b00 of size 15728640 by op training/Adam/Adam/update_dense_6/kernel/ResourceApplyAdam action_count 13055601068217568 step 44 next 119
# 2022-02-18 11:45:14.315192: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bfaf7b00 of size 15728640 by op training/Adam/Adam/update_dense_6/kernel/ResourceApplyAdam action_count 13055601068217569 step 44 next 122
# 2022-02-18 11:45:14.315196: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 6c09f7b00 of size 164937728 by op UNUSED action_count 0 step 0 next 100
# 2022-02-18 11:45:14.315199: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6ca743b00 of size 212123648 by op training/Adam/Adam/update_dense_7/kernel/ResourceApplyAdam action_count 13055601068217551 step 44 next 115
# 2022-02-18 11:45:14.315202: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6d718fb00 of size 290260224 by op training/Adam/Adam/update_dense_7/kernel/ResourceApplyAdam action_count 13055601068217552 step 44 next 18446744073709551615
# 2022-02-18 11:45:14.315204: I tensorflow/core/common_runtime/bfc_allocator.cc:1051]      Summary of in-use Chunks by size:
# 
I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 6bd9dd100 of size 676864 by op UNUSED action_count 0 step 0 next 94
# 2022-02-18 11:46:14.323367: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bda82500 of size 16384 by op training/Adam/Adam/update_dense_6/bias/ResourceApplyAdam action_count 13055601068217564 step 44 next 95
# 2022-02-18 11:46:14.323370: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bda86500 of size 16384 by op training/Adam/Adam/update_dense_6/bias/ResourceApplyAdam action_count 13055601068217565 step 44 next 113
# 2022-02-18 11:46:14.323383: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bda8a500 of size 16384 by op training/Adam/Adam/update_dense_6/bias/ResourceApplyAdam action_count 13055601068217566 step 44 next 121
# 2022-02-18 11:46:14.323391: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bda8e500 of size 12288 by op training/Adam/Adam/update_dense_5_1/kernel/ResourceApplyAdam action_count 13055601068217587 step 44 next 125
# 2022-02-18 11:46:14.323395: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bda91500 of size 12288 by op training/Adam/Adam/update_dense_5_1/kernel/ResourceApplyAdam action_count 13055601068217588 step 44 next 126
# 2022-02-18 11:46:14.323398: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bda94500 of size 256 by op SameWorkerRecvDone action_count 13055601068217612 step 0 next 129
# 2022-02-18 11:46:14.323401: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bda94600 of size 256 by op SameWorkerRecvDone action_count 13055601068217615 step 0 next 114
# 2022-02-18 11:46:14.323404: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bda94700 of size 512 by op training/Adam/Adam/update_dense_4_1/bias/ResourceApplyAdam action_count 13055601068217598 step 44 next 124
# 2022-02-18 11:46:14.323406: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bda94900 of size 512 by op training/Adam/Adam/update_dense_4_1/bias/ResourceApplyAdam action_count 13055601068217599 step 44 next 127
# 2022-02-18 11:46:14.323409: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bda94b00 of size 512 by op training/Adam/Adam/update_dense_4_1/bias/ResourceApplyAdam action_count 13055601068217600 step 44 next 128
# 2022-02-18 11:46:14.323412: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bda94d00 of size 51968 by op dense_23/bias/Initializer/zeros action_count 13055601068217871 step 0 next 149
# 2022-02-18 11:46:14.323415: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa1800 of size 256 by op dense_24/kernel/Initializer/random_uniform/min action_count 13055601068217873 step 0 next 150
# 2022-02-18 11:46:14.323418: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa1900 of size 256 by op dense_25/kernel/Initializer/random_uniform/min action_count 13055601068217874 step 0 next 151
# 2022-02-18 11:46:14.323421: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa1a00 of size 256 by op dense_25/kernel/Initializer/random_uniform/sub action_count 13055601068217875 step 0 next 152
# 2022-02-18 11:46:14.323424: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa1b00 of size 16384 by op dense_26/bias/Initializer/zeros action_count 13055601068217876 step 0 next 153
# 2022-02-18 11:46:14.323427: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa5b00 of size 256 by op dense_26/kernel/Initializer/random_uniform/min action_count 13055601068217877 step 0 next 154
# 2022-02-18 11:46:14.323430: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa5c00 of size 256 by op dense_26/kernel/Initializer/random_uniform/sub action_count 13055601068217878 step 0 next 155
# 2022-02-18 11:46:14.323433: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa5d00 of size 256 by op dense_27/kernel/Initializer/random_uniform/min action_count 13055601068217879 step 0 next 156
# 2022-02-18 11:46:14.323435: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa5e00 of size 512 by op dense_28/bias/Initializer/zeros action_count 13055601068217880 step 0 next 157
# 2022-02-18 11:46:14.323439: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa6000 of size 256 by op dense_28/kernel/Initializer/random_uniform/min action_count 13055601068217881 step 0 next 158
# 2022-02-18 11:46:14.323442: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa6100 of size 256 by op dense_29/kernel/Initializer/random_uniform/min action_count 13055601068217882 step 0 next 159
# 2022-02-18 11:46:14.323445: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa6200 of size 7680 by op dense_30/bias/Initializer/zeros action_count 13055601068217883 step 0 next 160
# 2022-02-18 11:46:14.323448: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa8000 of size 256 by op dense_30/kernel/Initializer/random_uniform/min action_count 13055601068217884 step 0 next 161
# 2022-02-18 11:46:14.323451: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa8100 of size 256 by op dense_30/kernel/Initializer/random_uniform/sub action_count 13055601068217885 step 0 next 162
# 2022-02-18 11:46:14.323454: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 6bdaa
I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 98 Chunks of size 256 totalling 24.5KiB
# 2022-02-18 11:46:14.323535: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 10 Chunks of size 512 totalling 5.0KiB
# 2022-02-18 11:46:14.323538: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 9 Chunks of size 768 totalling 6.8KiB
# 2022-02-18 11:46:14.323541: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 4 Chunks of size 1024 totalling 4.0KiB
# 2022-02-18 11:46:14.323544: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 1280 totalling 1.2KiB
# 2022-02-18 11:46:14.323547: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 7680 totalling 7.5KiB
# 2022-02-18 11:46:14.323550: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 8192 totalling 8.0KiB
# 2022-02-18 11:46:14.323553: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 8 Chunks of size 12288 totalling 96.0KiB
# 2022-02-18 11:46:14.323557: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 10 Chunks of size 16384 totalling 160.0KiB
# 2022-02-18 11:46:14.323560: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 32768 totalling 32.0KiB
# 2022-02-18 11:46:14.323563: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 11 Chunks of size 51968 totalling 558.2KiB
# 2022-02-18 11:46:14.323566: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 56320 totalling 55.0KiB
# 2022-02-18 11:46:14.323569: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 14745600 totalling 14.06MiB
# 2022-02-18 11:46:14.323573: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 5 Chunks of size 15728640 totalling 75.00MiB
# 2022-02-18 11:46:14.323576: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 15728896 totalling 15.00MiB
# 2022-02-18 11:46:14.323579: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 31457280 totalling 30.00MiB
# 2022-02-18 11:46:14.323582: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 3 Chunks of size 49716480 totalling 142.24MiB
# 2022-02-18 11:46:14.323584: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 118734848 totalling 113.23MiB
# 2022-02-18 11:46:14.323586: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 3 Chunks of size 212123648 totalling 606.89MiB
# 2022-02-18 11:46:14.323588: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 227783936 totalling 217.23MiB
# 2022-02-18 11:46:14.323591: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 290260224 totalling 276.81MiB
# 2022-02-18 11:46:14.323593: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 2 Chunks of size 670499328 totalling 1.25GiB
# 2022-02-18 11:46:14.323595: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 720151552 totalling 686.79MiB
# 2022-02-18 11:46:14.323597: I tensorflow/core/common_runtime/bfc_allocator.cc:1058] Sum Total of in-use chunks: 3.38GiB
# 2022-02-18 11:46:14.323599: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] total_region_allocated_bytes_: 3629514752 memory_limit_: 3629514752 available bytes: 0 curr_region_allocation_bytes_: 7259029504
# 2022-02-18 11:46:14.323604: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Stats:
# Limit:                      3629514752
# InUse:                      3625005824
# MaxInUse:                   3626775552
# NumAllocs:                         879
# MaxAllocSize:                720151552
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-02-18 11:46:14.323613: W tensorflow/core/common_runtime/bfc_allocator.cc:467] **************************************************************************************************xx
# 2022-02-18 11:46:14.323647: W tensorflow/core/framework/op_kernel.cc:1767] OP_REQUIRES failed at random_op.cc:74 : Resource exhausted: OOM when allocating tensor with shape[960,4096] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc

# %% [markdown]
# # 3. Build Agent with Keras-RL

# %%
def build_agent(model, actions):
    policy = BoltzmannQPolicy()
    memory = SequentialMemory(limit=80000, window_length=1)
    dqn = DQNAgent(model=model, memory=memory, policy=policy, 
                  nb_actions=actions, nb_steps_warmup=1000, target_model_update=1e-2)
    return dqn

# %%
env = WordleEnv(newWordEvery=1, showStatsEvery=8, showStatsEveryMove=False)
dqn = build_agent(model, actions)
dqn.compile(Adam(learning_rate=3e-4), metrics=['accuracy'])
dqn.fit(env, nb_steps=500000, visualize=False, verbose=1)
# Out:
# Target word: acock
#
# slmui     1|
# tdlmq     2|
# behhh     3|
# htaku     4|
# dauml     5|
# dskvy     6|
#           Wins: 0/1041
#  1363/10000 [===>..........................] - ETA: 4:57 - reward: -10.7131done, took 1056.830 seconds

# %%
model.save('/home/face9/dev/OpenAI-Reinforcement-Learning-with-Custom-Environment/wordle')
# Out:
# INFO:tensorflow:Assets written to: /home/face9/dev/OpenAI-Reinforcement-Learning-with-Custom-Environment/wordle/assets
